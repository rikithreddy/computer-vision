# %%
import matplotlib.pyplot as plt
import numpy as np

def convolution(gray,conv_filter):
    dimensions = gray.shape
    print gray.shape
    edges = np.zeros(dimensions)
    print dimensions
    for i in range(0,dimensions[0]-3):
        for j in range(0,dimensions[1]-3):
            edges[[i+1],[j+1]]  = np.sum(np.dot(conv_filter, gray[i:i+3,j:j+3]))  
                        
#             print edges[[i+1],[j+1]]


#             print np.dot(conv_filter, gray[i:i+3,j:j+3]).sum()

#             print conv_filter
    return edges

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

def sobel_edge(gray):
#     gray  =gray.astype('int8')
    sobel_filter_gx = np.array([[1,0,-1],[2,0,-2],[1,0,-1]])
    sobel_filter_gy = np.array([[1,2,1],[0,0,0],[-1,-2,-1]])
#     print(sobel_filter_gx)
    sobel_gx = convolution(gray,sobel_filter_gx)
    sobel_gy = convolution(gray,sobel_filter_gy)
    sobel_gx_sq =np.square(sobel_gx)
    sobel_gy_sq = np.square(sobel_gy)
    edges = np.add(sobel_gx_sq, sobel_gy_sq )
    edges = np.sqrt(edges.astype('float64'))
    div = np.divide(sobel_filter_gy,sobel_filter_gx)
    slope = np.arctan(div)
    
    return div,edges, np.absolute(sobel_gx).astype('int8') , np.absolute(sobel_gy)

img =plt.imread('./ball_1.jpg',1)
# print img.shape
gray = rgb2gray(img)
sobel = sobel_edge(gray)
# Out:
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: divide by zero encountered in divide

# %%
# plt.imshow(255-sobel.astype('int8'),cmap='gray')
# np.dot(  gray)



# plt.imshow (np.abs(sobel[0]  )  ,cmap='gray')
# plt.show()
plt.imshow (sobel[1],cmap='gray')
plt.show()
# print(sobel[1])

# import cv2
# sobelx = cv2.Sobel(img,2,1,0,ksize=3)
# sobely = cv2.Sobel(img,2,0,1,ksize=3)

# plt.imshow(np.absolute(sobelx[:,:,1]),cmap = 'gray')
# plt.show()
np.unique(sobel[3])
# cv2.CV_64F
# np.sum(sobelx[0] - sobel[2])
# Out:
# array([0.00000000e+00, 5.68434189e-14, 1.13686838e-13, 2.27373675e-13])

# %%
from os import listdir
path = '../data/hard/'
output_path = '../output_sobel/hard/'

directories = listdir(path)


for directory in directories:
    list_path = path+directory
    if directory[0]=='.':
        continue        
    files_dir = listdir(list_path)
    for file in files_dir:
            if file[0]=='.':
                continue
            file_path  = list_path+'/'+file
            print file_path
            img =plt.imread(file_path,1)
            gray = rgb2gray(img)
            sobel = sobel_edge(gray)

            

            plt.imsave( output_path+file.split('.')[0]+'.png' ,sobel[1],cmap = 'gray' )




# file_path = '../data/easy/brick/brick_2.jpg'
# img =plt.imread(file_path,1)
# gray = rgb2gray(img)
# sobel = sobel_edge(gray)
# sobel[1] 

# np.reshape(sobel[1], (sobel[1].shape[0],sobel[1].shape[1],1))
# Out:
# ../data/hard/brick/brick_4.jpg
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: divide by zero encountered in divide
# ../data/hard/brick/brick_5.jpg
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# ../data/hard/brick/brick_8.jpg
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# ../data/hard/brick/brick_3.jpg
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# ../data/hard/brick/brick_1.jpg
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# ../data/hard/brick/brick_6.jpg
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# ../data/hard/brick/brick_7.jpg
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# ../data/hard/brick/brick_2.jpg
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# ../data/hard/ball/P1960558.JPG
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# ../data/hard/ball/ball_8.jpg
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# ../data/hard/ball/ball_2.jpg
# ...
